-- %%
SELECT count(*) AS total_count 
FROM tweets_bronze;

-- %%
SELECT 
  user, 
  text, 
  source_file, 
  processing_time 
FROM tweets_bronze 
LIMIT 10;

-- %%
SELECT 
  count(*) - count(date) as missing_dates,
  count(*) - count(sentiment) as missing_sentiments
FROM tweets_bronze;
