-- %%
SELECT COUNT(*) FROM workspace.default.tweets_silver;

-- %%
SELECT text, cleaned_text
FROM workspace.default.tweets_silver
LIMIT 10;

-- %%
SELECT DISTINCT mention
FROM workspace.default.tweets_silver
LIMIT 20;

-- %%
SELECT *
FROM workspace.default.tweets_silver
WHERE mention IS NULL
LIMIT 10;

-- %%
DESCRIBE workspace.default.tweets_silver;
